# %% [markdown]
# *Ejercicio 2*
#
# Una compañía fabrica dos tipos de motores pequeños con combustible sólido. Con el motor A gana 3 por motor y con el motor B gana 4 por motor. Dispone de 80 horas por semana para producirlos y en los procesos se requieren: 4 h para A y solo 2 h para B. Sin embargo, debido a lo peligroso del material usado, son necesarias 5 h de preparación y limpieza para el motopr B y 2 h para A. El tiempo de preparación total disponible es 120 h por semana. Determinar el número de cada clase de motores a producir que dé como resultado la máxima ganancia

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot([80/4, 0], [0, 80/2], color='orange', alpha=0.25)
plt.fill_between([80/4, 0], [0, 80/2], color='orange', alpha=0.25, label='Produccion')

plt.xlabel('Motor A')
plt.ylabel('Motor B')
plt.legend()
plt.show()

# %%
plt.figure()
    
# Restricción para M1
plt.plot([80/4, 0], [0, 80/2], color='orange', alpha=0.25)
plt.fill_between([80/4, 0], [0, 80/2], color='orange', alpha=0.25, label='Produccion')

# Restricción para M2
plt.plot([120/2, 0], [0, 120/5 ], color='blue', alpha=0.125)
plt.fill_between([120/2, 0], [0, 120/5 ], color='blue', alpha=0.125, label='Preparacion')

plt.xlabel('Motor A')
plt.ylabel('Motor B')
plt.legend()
plt.show()

# %%
plt.figure()
    
# Restricción para M1
plt.plot([80/4, 0], [0, 80/2], color='orange', alpha=0.25)
plt.fill_between([80/4, 0], [0, 80/2], color='orange', alpha=0.25, label='Produccion')

# Restricción para M2
plt.plot([120/2, 0], [0, 120/5 ], color='blue', alpha=0.125)
plt.fill_between([120/2, 0], [0, 120/5 ], color='blue', alpha=0.125, label='Preparacion')

plt.xlabel('Motor A')
plt.ylabel('Motor B')

plt.scatter([10], [20])  # punto factible
plt.plot([0, 110/3],[110/4, 0], color='red', linestyle='-.')

plt.xlim(0)
plt.ylim(0)

plt.legend()
plt.show()
