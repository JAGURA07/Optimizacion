# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
a=-5
b=5
T=np.linspace(a,b,100)
U=(T*T+T)*np.cos(2*T)+T*T

# %%
plt.plot(T,U,'k')
plt.xlabel('Temperatura')
plt.ylabel('Costo')
plt.show()
