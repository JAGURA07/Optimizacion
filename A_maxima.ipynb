# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return x/2-x*x

# %%
x = np.arange(0,1,0.01)

# %%
plt.plot(x, [f(i) for i in x])
plt.xlim(0, 0.5)
plt.ylim(0, 0.07)
plt.title("Area Maxima")
plt.text(0.25,0.0625,"")
plt.plot(0.25,0.0625, 'r--o', label="Partícula 1")
plt.show()
