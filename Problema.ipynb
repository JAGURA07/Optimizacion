# %%
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt

# %%
def f(x):
    return x[0]**2-2*x[0]+x[1]

# %%
x = np.linspace(0, 3, 100)
y = np.linspace(0, 3, 100)
X, Y = np.meshgrid(x, y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))
plt.figure(figsize=(10,8))
plt.contour(X, Y, Z, np.arange(-10,10, 0.5), cmap='jet');
plt.plot(x, 1-x, 'k:', linewidth=1)
plt.plot(x, (2-x)/4, 'k:', linewidth=1)
plt.xlabel(''); plt.ylabel(''); 
plt.title("Proyección en el plano XY")
plt.axis([0,3,0,3])
# Out:
# (0.0, 3.0, 0.0, 3.0)

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x: np.array([-x[0]-4*x[1]+2],([x[0]+x[1]-1]))})

bnds = ((0, 2.0), (0, 2.0))

# %%
x0 = [0.5, 0.5]

# %%
cx = opt.minimize(f, x0, bounds=bnds, constraints=None)
cx
# Out:
#       fun: -1.0
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([0.        , 1.00000001])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 3
#      njev: 4
#    status: 0
#   success: True
#         x: array([1., 0.])

# %%
def f(x):
    return (x[0]**2+x[1]**2+x[1]-1)*-1

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))
plt.figure(figsize=(10,8))
plt.contour(X, Y, Z, np.arange(-10,10, 0.5), cmap='jet');
plt.plot(x, np.sqrt(1-x**2), 'k:', linewidth=2)
plt.plot(x, -np.sqrt(1-x**2), 'k:', linewidth=2)
plt.xlabel(''); plt.ylabel(''); 
plt.title("Proyección en el plano XY")
plt.axis([-2,2,-2,2])
# Out:
# <ipython-input-105-d3c747f6e20b>:7: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, np.sqrt(1-x**2), 'k:', linewidth=2)
# <ipython-input-105-d3c747f6e20b>:8: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -np.sqrt(1-x**2), 'k:', linewidth=2)
# (-2.0, 2.0, -2.0, 2.0)

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x:np.array([1-x[0]**2-x[1]**2])})
bnds = ((-1, 1), (-1, 1))

# %%
x0 = [0.0,0.0 ]

# %%
cx = opt.minimize(f, x0,bounds=bnds, constraints=None)
cx
# Out:
#       fun: -1.0
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-4.44089210e-08, -2.99999997e+00])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 6
#       nit: 1
#      njev: 2
#    status: 0
#   success: True
#         x: array([1.11022302e-08, 1.00000000e+00])

# %%
def f(x):
    return (x[0]*x[1]*x[2])*-1

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x:np.array([-x[0]**2-x[1]**2-x[2]**2+1])})
bnds = ((-1, 1), (-1, 1),(-1,1))

# %%
#cx = opt.minimize(f, x0,bounds=bnds, constraints=None)

# %%
def f(x):
    return (-x[0]**2-x[1]**2+1)*-1

# %%
x = np.linspace(0, 4, 100)
y = np.linspace(0, 4, 100)
X, Y = np.meshgrid(x, y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))
plt.figure(figsize=(10,8))
plt.contour(X, Y, Z, np.arange(-10,10, 0.5), cmap='jet');
plt.xlabel(''); plt.ylabel(''); 
plt.title("Proyección en el plano XY")
plt.axis([0,4,0,4])
# Out:
# (0.0, 4.0, 0.0, 4.0)

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x:np.array([2-x[0]],([3-x[1]]))})
bnds = ((2, 10), (3, 10))

# %%
x0 = [0.5, 0.5]

# %%
cx = opt.minimize(f, x0,bounds=bnds, constraints=None)
cx
# Out:
#       fun: 12.0
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([4., 6.])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 3
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([2., 3.])

# %%
def f(x):
    return 4*np.log(x[0]**2+2)+x[1]**2

# %%
x = np.linspace(0, 4, 100)
y = np.linspace(0, 4, 100)
X, Y = np.meshgrid(x, y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))
plt.figure(figsize=(10,8))
plt.contour(X, Y, Z, np.arange(-10,10, 0.5), cmap='jet');
plt.plot(x, 2-x**2, 'k:', linewidth=2)
plt.xlabel(''); plt.ylabel(''); 
plt.title("Proyección en el plano XY")
plt.axis([0,4,0,4])
# Out:
# (0.0, 4.0, 0.0, 4.0)

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x:np.array([x[0]**2+x[1]-2],[x[0]-1])})
bnds = ((1, 4), (1, 4))

# %%
x0 = [0.5, 0.5]

# %%
cx = opt.minimize(f, x0,bounds=bnds, constraints=None)
cx
# Out:
#       fun: 5.394449154672439
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([2.66666664, 2.        ])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 3
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([1., 1.])

# %%
def f(x):
    return (x[0]*x[1]*np.exp(x[0]+x[1]))*1

# %%
x = np.linspace(0, -2, 100)
y = np.linspace(0, -2, 100)
X, Y = np.meshgrid(x, y)
Z = f(np.vstack([X.ravel(), Y.ravel()])).reshape((100,100))
plt.figure(figsize=(10,8))
plt.contour(X, Y, Z, np.arange(-0.5,0.1, 0.01), cmap='jet');
plt.plot(x, np.sqrt(1-(x+1)**2)-1, 'k:', linewidth=2)
plt.plot(x, -np.sqrt(1-(x+1)**2)-1, 'k:', linewidth=2)
plt.xlabel(''); plt.ylabel(''); 
plt.title("Proyección en el plano XY")
plt.axis([0,-2,0,-2])
# Out:
# (0.0, -2.0, 0.0, -2.0)

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x:np.array([1-(x[0]+1)**2-(x[1]+1)**2])})
bnds = ((-2, 0), (-2, 0))

# %%
x0 = [-1, -0.5]

# %%
cx = opt.minimize(f, x0,bounds=bnds, constraints=None)
cx
# Out:
#       fun: -0.0
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.        , -0.36787944])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 12
#       nit: 2
#      njev: 4
#    status: 0
#   success: True
#         x: array([-1.,  0.])

# %%
def f(x):
    return (x[0]*x[1]*np.exp(x[0]+x[1]))*-1

# %%
cons = ({'type': 'ineq',
         'fun' : lambda x:np.array([1-(x[0]+1)**2-(x[1]+1)**2])})
bnds = ((-2, 0), (-2, 0))

# %%
x0 = [-0.5, -0.5]

# %%
cx = opt.minimize(f, x0,bounds=bnds, constraints=None)
cx
# Out:
#       fun: -0.13533528323621216
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([2.33146834e-07, 2.33146834e-07])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 18
#       nit: 5
#      njev: 6
#    status: 0
#   success: True
#         x: array([-0.99999828, -0.99999828])
